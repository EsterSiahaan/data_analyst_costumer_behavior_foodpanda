# %%
# Load datasetnya menggunakan pandas    

import pandas as pd
import numpy as np

df = pd.read_csv('../datasets/foodpanda_analysis_dataset.csv', encoding='utf-8')  

df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  quantity    price payment_method  \
# 0      McDonald's    Burger  Italian         5  1478.27           Cash
# 1             KFC    Burger  Italian         3   956.04         Wallet
# 2       Pizza Hut     Fries  Italian         2   882.51           Cash
# 3          Subway     Pizza  Dessert         4   231.30           Card
# 4             KFC  Sandwich  Dessert         1  1156.69           Cash
#
#    order_frequency last_order_date  loyalty_points   churned  rating  \
# ...

# %%
# Menampilkan 5 baris pertama dari dataset

df.head()
# Out:
#   customer_id  gender     age      city signup_date order_id order_date  \
# 0       C5663    Male   Adult  Peshawar   1/14/2024    O9663  8/23/2023
# 1       C2831    Male   Adult    Multan    7/7/2024    O6831  8/23/2023
# 2       C2851   Other  Senior    Multan   6/20/2025    O6851  8/23/2023
# 3       C1694  Female  Senior  Peshawar    9/5/2023    O5694  8/23/2023
# 4       C4339   Other  Senior    Lahore  12/29/2023    O8339  8/24/2023
#
#   restaurant_name dish_name category  quantity    price payment_method  \
# 0      McDonald's    Burger  Italian         5  1478.27           Cash
# 1             KFC    Burger  Italian         3   956.04         Wallet
# 2       Pizza Hut     Fries  Italian         2   882.51           Cash
# 3          Subway     Pizza  Dessert         4   231.30           Card
# 4             KFC  Sandwich  Dessert         1  1156.69           Cash
#
#    order_frequency last_order_date  loyalty_points   churned  rating  \
# ...

# %%
# Mengecek informasi dataset dan tipe data setiap kolom

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      6000 non-null   str
#  1   gender           6000 non-null   str
#  2   age              6000 non-null   str
#  3   city             6000 non-null   str
#  4   signup_date      6000 non-null   str
#  5   order_id         6000 non-null   str
#  6   order_date       6000 non-null   str
#  7   restaurant_name  6000 non-null   str
#  8   dish_name        6000 non-null   str
#  9   category         6000 non-null   str
#  10  quantity         6000 non-null   int64
#  11  price            6000 non-null   float64
#  12  payment_method   6000 non-null   str
#  13  order_frequency  6000 non-null   int64
#  14  last_order_date  6000 non-null   str
#  15  loyalty_points   6000 non-null   int64
#  16  churned          6000 non-null   str
#  17  rating           6000 non-null   int64
# ...

# %%
# Mengecek jumlah nilai yang hilang (missing values) di setiap kolom

df.isnull().sum()
# Out:
# customer_id        0
# gender             0
# age                0
# city               0
# signup_date        0
# order_id           0
# order_date         0
# restaurant_name    0
# dish_name          0
# category           0
# quantity           0
# price              0
# payment_method     0
# order_frequency    0
# last_order_date    0
# loyalty_points     0
# churned            0
# rating             0
# rating_date        0
# delivery_status    0
# dtype: int64

# %%
# 

df.describe(include='all')
# Out:
#        customer_id  gender       age    city signup_date order_id order_date  \
# count         6000    6000      6000    6000        6000     6000       6000
# unique        6000       3         3       5         730     6000        730
# top          C5663  Female  Teenager  Multan  10/18/2023    O9663   9/8/2024
# freq             1    2018      2062    1256          18        1         20
# mean           NaN     NaN       NaN     NaN         NaN      NaN        NaN
# std            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# min            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# 25%            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# 50%            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# 75%            NaN     NaN       NaN     NaN         NaN      NaN        NaN
# max            NaN     NaN       NaN     NaN         NaN      NaN        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date', 'order_id',
#        'order_date', 'restaurant_name', 'dish_name', 'category', 'quantity',
#        'price', 'payment_method', 'order_frequency', 'last_order_date',
#        'loyalty_points', 'churned', 'rating', 'rating_date',
#        'delivery_status'],
#       dtype='str')

# %%
df.dtypes
# Out:
# customer_id            str
# gender                 str
# age                    str
# city                   str
# signup_date            str
# order_id               str
# order_date             str
# restaurant_name        str
# dish_name              str
# category               str
# quantity             int64
# price              float64
# payment_method         str
# order_frequency      int64
# last_order_date        str
# loyalty_points       int64
# churned                str
# rating               int64
# rating_date            str
# delivery_status        str
# dtype: object

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'], format='%m/%d/%Y')
df['order_date'] = pd.to_datetime(df['order_date'], format='%m/%d/%Y')
df['rating_date'] = pd.to_datetime(df['rating_date'], format='%m/%d/%Y')
df.dtypes
# Out:
# customer_id                   str
# gender                        str
# age                           str
# city                          str
# signup_date        datetime64[us]
# order_id                      str
# order_date         datetime64[us]
# restaurant_name               str
# dish_name                     str
# category                      str
# quantity                    int64
# price                     float64
# payment_method                str
# order_frequency             int64
# last_order_date               str
# loyalty_points              int64
# churned                       str
# rating                      int64
# rating_date        datetime64[us]
# delivery_status               str
# dtype: object

# %%
df['last_order_date'] = pd.to_datetime(df['last_order_date'], format='%m/%d/%Y')

# %%
df.head(60)
# Out:
#    customer_id  gender       age       city signup_date order_id order_date  \
# 0        C5663    Male     Adult   Peshawar  2024-01-14    O9663 2023-08-23
# 1        C2831    Male     Adult     Multan  2024-07-07    O6831 2023-08-23
# 2        C2851   Other    Senior     Multan  2025-06-20    O6851 2023-08-23
# 3        C1694  Female    Senior   Peshawar  2023-09-05    O5694 2023-08-23
# 4        C4339   Other    Senior     Lahore  2023-12-29    O8339 2023-08-24
# 5        C6543   Other     Adult    Karachi  2023-09-28   O10543 2023-08-24
# 6        C6423    Male     Adult     Lahore  2025-04-08   O10423 2023-08-24
# 7        C4621    Male     Adult   Peshawar  2024-02-05    O8621 2023-08-24
# 8        C5146   Other    Senior    Karachi  2024-12-17    O9146 2023-08-24
# 9        C3579    Male     Adult    Karachi  2023-10-13    O7579 2023-08-24
# 10       C5535    Male     Adult     Lahore  2025-07-30    O9535 2023-08-24
# ...

# %%
labels = ['New Customer', 'Occasional', 'Regular', 'Loyal', 'VIP']

df['loyalty_group'] = pd.cut(
    df['loyalty_points'],
    bins=[0,100,200,300,400,500],
    labels=labels
)

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="postgres",
    user="postgres",
    password="admin12345",
    port="5432"
)

print("Berhasil connect")
# Out:
# Berhasil connect

# %%
from sqlalchemy import create_engine, text

engine = create_engine(
    "postgresql+psycopg2://postgres:admin12345@localhost:5432/postgres"
)

try:
    with engine.connect() as conn:
        result = conn.execute(text("SELECT 1"))
        print("Koneksi berhasil, SELECT 1 =", result.scalar())
except Exception as e:
    print("Koneksi gagal:", e)
# Out:
# Koneksi berhasil, SELECT 1 = 1

# %%
df.to_sql(
    "customer_behavior_foodpanda",
    engine,
    if_exists="replace",
    index=False, 
    schema="project_data_analisis"
)
# Out:
# 1000
